# %%
from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage
import numpy as np

# %%
x = np.array([[1,2],[3.5,5.5],[3,3],[5,2.5],[5,3.5]])

# %%
print(x)
# Out:
# [[1.  2. ]
#  [3.5 5.5]
#  [3.  3. ]
#  [5.  2.5]
#  [5.  3.5]]

# %%
Z = linkage(x)

# %%
print(Z)
# Out:
# [[3.         4.         1.         2.        ]
#  [2.         5.         2.06155281 3.        ]
#  [0.         6.         2.23606798 4.        ]
#  [1.         7.         2.5        5.        ]]

# %%
plt.figure(figsize=(25, 10))
plt.title('Dendrogram Hierarchical Klastering')
plt.xlabel('Data')
plt.ylabel('Jarak')
dendrogram(Z)
plt.show()
